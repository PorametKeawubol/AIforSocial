# %% [markdown]
# Understanding Synset

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet

syn = wordnet.synsets('hello')[0]
print ("Synset name : ", syn.name())
# defining the word
print ("\nSynset meaning : ", syn.definition())
# list of phrases that use the word in context
print ("\nSynset example : ", syn.examples())
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Synset name :  hello.n.01
#
# Synset meaning :  an expression of greeting
#
# Synset example :  ['every morning they exchanged polite hellos']

# %% [markdown]
# Understanding Hypernorms and Hyponyms

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet

syn = wordnet.synsets('hello')[0]

print ("Synset name : ", syn.name())
print ("\nSynset abstract term : ", syn.hypernyms())
print ("\nSynset specific term : ",
	syn.hypernyms()[0].hyponyms())

syn.root_hypernyms()

print ("\nSynset root hypernerm : ", syn.root_hypernyms())
# Out:
# Synset name :  hello.n.01
#
# Synset abstract term :  [Synset('greeting.n.01')]
#
# Synset specific term :  [Synset('welcome.n.02'), Synset('good_afternoon.n.01'), Synset('hello.n.01'), Synset('reception.n.01'), Synset('regard.n.03'), Synset('salute.n.02'), Synset('good_morning.n.01'), Synset('calling_card.n.02'), Synset('well-wishing.n.01'), Synset('hail.n.03'), Synset('salute.n.03'), Synset('pax.n.01')]
#
# Synset root hypernerm :  [Synset('entity.n.01')]
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# Part of Speech (POS) in Synset.

# %%
syn = wordnet.synsets('hello')[0]
print ("Syn tag : ", syn.pos())

syn = wordnet.synsets('doing')[0]
print ("Syn tag : ", syn.pos())

syn = wordnet.synsets('beautiful')[0]
print ("Syn tag : ", syn.pos())

syn = wordnet.synsets('quickly')[0]
print ("Syn tag : ", syn.pos())
# Out:
# Syn tag :  n
# Syn tag :  v
# Syn tag :  a
# Syn tag :  r

# %%
syn1 = wordnet.synsets('beautiful')[0]
syn1
# Out:
# Synset('beautiful.a.01')

# %%
syn2 = wordnet.synsets('beautiful')[1]
syn2
# Out:
# Synset('beautiful.s.02')

# %% [markdown]
# Example of several synsets and their POS

# %%
words = ['test', 'teast', 'toast']

# %%
for word in words:
    synsets = wordnet.synsets(word)

    for synset in synsets:
        print(synset.pos) #prints part of speech
# Out:
# <bound method Synset.pos of Synset('trial.n.02')>
# <bound method Synset.pos of Synset('test.n.02')>
# <bound method Synset.pos of Synset('examination.n.02')>
# <bound method Synset.pos of Synset('test.n.04')>
# <bound method Synset.pos of Synset('test.n.05')>
# <bound method Synset.pos of Synset('test.n.06')>
# <bound method Synset.pos of Synset('test.v.01')>
# <bound method Synset.pos of Synset('screen.v.01')>
# <bound method Synset.pos of Synset('quiz.v.01')>
# <bound method Synset.pos of Synset('test.v.04')>
# <bound method Synset.pos of Synset('test.v.05')>
# <bound method Synset.pos of Synset('test.v.06')>
# <bound method Synset.pos of Synset('test.v.07')>
# <bound method Synset.pos of Synset('toast.n.01')>
# <bound method Synset.pos of Synset('toast.n.02')>
# <bound method Synset.pos of Synset('goner.n.01')>
# <bound method Synset.pos of Synset('pledge.n.03')>
# <bound method Synset.pos of Synset('crispen.v.01')>
# <bound method Synset.pos of Synset('toast.v.02')>

# %% [markdown]
# WordNet Interface

# %%
#from nltk.corpus import wordnet

# %%
import nltk

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import wordnet as wn

# %% [markdown]
# Words

# %% [markdown]
# Look up a word using synsets(); this function has an optional pos argument which lets you constrain the part of speech of the word:

# %%
wn.synsets('dog')
# Out:
# [Synset('dog.n.01'),
#  Synset('frump.n.01'),
#  Synset('dog.n.03'),
#  Synset('cad.n.01'),
#  Synset('frank.n.02'),
#  Synset('pawl.n.01'),
#  Synset('andiron.n.01'),
#  Synset('chase.v.01')]

# %%
wn.synsets('dog', pos=wn.VERB)
# Out:
# [Synset('chase.v.01')]

# %% [markdown]
# The other parts of speech are NOUN, ADJ and ADV. A synset is identified with a 3-part name of the form: word.pos.nn:

# %%
wn.synset('dog.n.01')
# Out:
# Synset('dog.n.01')

# %%
print(wn.synset('dog.n.01').definition())
# Out:
# a member of the genus Canis (probably descended from the common wolf) that has been domesticated by man since prehistoric times; occurs in many breeds

# %%
len(wn.synset('dog.n.01').examples())
# Out:
# 1

# %%
print(wn.synset('dog.n.01').examples()[0])
# Out:
# the dog barked all night

# %%
wn.synset('dog.n.01').lemmas()
# Out:
# [Lemma('dog.n.01.dog'),
#  Lemma('dog.n.01.domestic_dog'),
#  Lemma('dog.n.01.Canis_familiaris')]

# %%
[str(lemma.name()) for lemma in wn.synset('dog.n.01').lemmas()]
# Out:
# ['dog', 'domestic_dog', 'Canis_familiaris']

# %%
wn.lemma('dog.n.01.dog').synset()
# Out:
# Synset('dog.n.01')

# %%
dogs = wn.lemma('dog.n.01.dog')
dogs.count()
# Out:
# 42

# %%
dogs = wn.synsets('dog')
for ss in dogs:
  print(ss.definition())
# Out:
# a member of the genus Canis (probably descended from the common wolf) that has been domesticated by man since prehistoric times; occurs in many breeds
# a dull unattractive unpleasant girl or woman
# informal term for a man
# someone who is morally reprehensible
# a smooth-textured sausage of minced beef or pork usually smoked; often served on a bread roll
# a hinged catch that fits into a notch of a ratchet to move a wheel forward or prevent it from moving backward
# metal supports for logs in a fireplace
# go after with the intent to catch

# %%
cats = wn.synsets('cat')
for ss in cats:
  print(ss.definition())
# Out:
# feline mammal usually having thick soft fur and no ability to roar: domestic cats; wildcats
# an informal term for a youth or man
# a spiteful woman gossip
# the leaves of the shrub Catha edulis which are chewed like tobacco or used to make tea; has the effect of a euphoric stimulant
# a whip with nine knotted cords
# a large tracked vehicle that is propelled by two endless metal belts; frequently used for moving earth in construction and farm work
# any of several large cats typically able to roar and living in the wild
# a method of examining body organs by scanning them with X rays and using a computer to construct a series of cross-sectional scans along a single axis
# beat with a cat-o'-nine-tails
# eject the contents of the stomach through the mouth

# %% [markdown]
# The WordNet corpus reader gives access to the Open Multilingual WordNet, using ISO-639 language codes. These languages are not loaded by default, but only lazily, when needed.

# %%
wn.langs()
# Out:
# ['eng']

# %% [markdown]
# The synonyms of a word are returned as a nested list of synonyms of the different senses of the input word in the given language, since these different senses are not mutual synonyms:

# %%
wn.synonyms('car')
# Out:
# [['auto', 'automobile', 'machine', 'motorcar'],
#  ['railcar', 'railroad_car', 'railway_car'],
#  ['gondola'],
#  ['elevator_car'],
#  ['cable_car']]

# %% [markdown]
# Synsets
# Synset: a set of synonyms that share a common meaning.

# %%
dog = wn.synset('dog.n.01')

# %%
dog.hypernyms()
# Out:
# [Synset('domestic_animal.n.01'), Synset('canine.n.02')]

# %%
dog.hyponyms()
# Out:
# [Synset('newfoundland.n.01'),
#  Synset('corgi.n.01'),
#  Synset('leonberg.n.01'),
#  Synset('cur.n.01'),
#  Synset('pug.n.01'),
#  Synset('dalmatian.n.02'),
#  Synset('lapdog.n.01'),
#  Synset('pooch.n.01'),
#  Synset('spitz.n.01'),
#  Synset('basenji.n.01'),
#  Synset('griffon.n.02'),
#  Synset('great_pyrenees.n.01'),
#  Synset('poodle.n.01'),
#  Synset('toy_dog.n.01'),
#  Synset('mexican_hairless.n.01'),
#  Synset('puppy.n.01'),
#  Synset('working_dog.n.01'),
#  Synset('hunting_dog.n.01')]

# %%
dog.member_holonyms()
# Out:
# [Synset('pack.n.06'), Synset('canis.n.01')]

# %%
dog.root_hypernyms()
# Out:
# [Synset('entity.n.01')]

# %%
wn.synset('dog.n.01').lowest_common_hypernyms(wn.synset('cat.n.01'))
# Out:
# [Synset('carnivore.n.01')]

# %% [markdown]
# Each synset contains one or more lemmas, which represent a specific sense of a specific word.
#
# Note that some relations are defined by WordNet only over Lemmas:

# %%
good = wn.synset('good.a.01')

# %%
good.lemmas()[0].antonyms()
# Out:
# [Lemma('bad.a.01.bad')]

# %% [markdown]
# Lemmas

# %%
eat = wn.lemma('eat.v.03.eat')

# %%
eat
# Out:
# Lemma('feed.v.06.eat')

# %%
eat.count()
# Out:
# 4

# %%
wn.lemma_from_key(eat.key())
# Out:
# Lemma('feed.v.06.eat')

# %%
wn.lemma_from_key(eat.key()).synset()
# Out:
# Synset('feed.v.06')

# %% [markdown]
# Similarity

# %% [markdown]
# Introducing synset

# %%
dog = wn.synset('dog.n.01')
cat = wn.synset('cat.n.01')

# %%
hit = wn.synset('hit.v.01')

# %%
slap = wn.synset('slap.v.01')

# %% [markdown]
# Path Similarity

# %%
dog.path_similarity(cat)
# Out:
# 0.2

# %%
hit.path_similarity(slap)
# Out:
# 0.14285714285714285

# %%
wn.path_similarity(hit, slap)
# Out:
# 0.14285714285714285

# %% [markdown]
# Another way to introducing Synsets and get path similarity

# %%
from nltk.corpus import wordnet

syn1 = wordnet.synsets('hello')[0]
syn2 = wordnet.synsets('selling')[0]

print ("hello name : ", syn1.name())
print ("selling name : ", syn2.name())
# Out:
# hello name :  hello.n.01
# selling name :  selling.n.01

# %%
print ("\nSynset meaning : ", syn1.definition())
# Out:
# Synset meaning :  an expression of greeting

# %%
print ("\nSynset example : ", syn1.examples())
# Out:
# Synset example :  ['every morning they exchanged polite hellos']

# %%
syn1.path_similarity(syn2)
# Out:
# 0.08333333333333333

# %% [markdown]
# Lin Similarity

# %%
import nltk

# %%
nltk.download('wordnet_ic')
# Out:
# [nltk_data] Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet_ic.zip.
# True

# %%
from nltk.corpus import wordnet_ic

# %%
brown_ic = wordnet_ic.ic('ic-brown.dat')
semcor_ic = wordnet_ic.ic('ic-semcor.dat')

# %%
dog = wn.synset('dog.n.01')
cat = wn.synset('cat.n.01')

# %%
dog.lin_similarity(cat, semcor_ic)
# Out:
# 0.8863288628086228

# %%
dog.lin_similarity(cat, brown_ic)
# Out:
# 0.8768009843733973

# %% [markdown]
# Comparing Path and Lin

# %%
import nltk
from nltk.corpus import wordnet as wn

# %%
deer = wordnet.synset('deer.n.01')
elk = wordnet.synset('elk.n.01')
horse = wordnet.synset('horse.n.01')
dog = wordnet.synset('dog.n.01')

# %%
deer.path_similarity(elk)
# Out:
# 0.5

# %%
elk.path_similarity(deer)
# Out:
# 0.5

# %%
import nltk
nltk.download('wordnet_ic')
from nltk.corpus import wordnet_ic
brown_ic = wordnet_ic.ic('ic-brown.dat')
# Out:
# [nltk_data] Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]   Package wordnet_ic is already up-to-date!

# %%
deer.lin_similarity(elk, brown_ic)
# Out:
# 0.8623778273893673

# %%
deer.lin_similarity(horse, brown_ic)
# Out:
# 0.7726998936065773

# %%
dog.lin_similarity(horse, brown_ic)
# Out:
# 0.6466145695634766

# %% [markdown]
# Access to all Synsets
# Iterate over all the noun synsets:

# %%
for synset in list(wn.all_synsets('n'))[:10]:
   print(synset)
# Out:
# Synset('entity.n.01')
# Synset('physical_entity.n.01')
# Synset('abstraction.n.06')
# Synset('thing.n.12')
# Synset('object.n.01')
# Synset('whole.n.02')
# Synset('congener.n.03')
# Synset('living_thing.n.01')
# Synset('organism.n.01')
# Synset('benthos.n.02')

# %% [markdown]
# Get all synsets for this word, possibly restricted by POS:

# %%
wn.synsets('dog')
# Out:
# [Synset('dog.n.01'),
#  Synset('frump.n.01'),
#  Synset('dog.n.03'),
#  Synset('cad.n.01'),
#  Synset('frank.n.02'),
#  Synset('pawl.n.01'),
#  Synset('andiron.n.01'),
#  Synset('chase.v.01')]

# %%
wn.synsets('dog', pos='v')
# Out:
# [Synset('chase.v.01')]

# %% [markdown]
# Walk through the noun synsets looking at their hypernyms:

# %%
from itertools import islice
for synset in islice(wn.all_synsets('n'), 5):
   print(synset, synset.hypernyms())
# Out:
# Synset('entity.n.01') []
# Synset('physical_entity.n.01') [Synset('entity.n.01')]
# Synset('abstraction.n.06') [Synset('entity.n.01')]
# Synset('thing.n.12') [Synset('physical_entity.n.01')]
# Synset('object.n.01') [Synset('physical_entity.n.01')]

# %% [markdown]
# Synset Closures

# %% [markdown]
# Compute transitive closures of synsets

# %%
dog = wn.synset('dog.n.01')

# %%
hypo = lambda s: s.hyponyms()

# %%
hyper = lambda s: s.hypernyms()

# %%
list(dog.closure(hypo, depth=1)) == dog.hyponyms()
# Out:
# True

# %%
list(dog.closure(hyper, depth=1)) == dog.hypernyms()
# Out:
# True

# %%
list(dog.closure(hypo))
# Out:
# [Synset('newfoundland.n.01'),
#  Synset('corgi.n.01'),
#  Synset('leonberg.n.01'),
#  Synset('cur.n.01'),
#  Synset('pug.n.01'),
#  Synset('dalmatian.n.02'),
#  Synset('lapdog.n.01'),
#  Synset('pooch.n.01'),
#  Synset('spitz.n.01'),
#  Synset('basenji.n.01'),
#  Synset('griffon.n.02'),
#  Synset('great_pyrenees.n.01'),
#  Synset('poodle.n.01'),
#  Synset('toy_dog.n.01'),
#  Synset('mexican_hairless.n.01'),
#  Synset('puppy.n.01'),
#  Synset('working_dog.n.01'),
#  Synset('hunting_dog.n.01'),
#  Synset('cardigan.n.02'),
#  Synset('pembroke.n.01'),
#  Synset('pariah_dog.n.01'),
#  Synset('feist.n.01'),
#  Synset('liver-spotted_dalmatian.n.01'),
#  Synset('keeshond.n.01'),
#  Synset('pomeranian.n.01'),
#  Synset('samoyed.n.03'),
#  Synset('chow.n.03'),
#  Synset('brabancon_griffon.n.01'),
#  Synset('toy_poodle.n.01'),
#  Synset('standard_poodle.n.01'),
#  Synset('large_poodle.n.01'),
#  Synset('miniature_poodle.n.01'),
#  Synset('chihuahua.n.03'),
#  Synset('toy_spaniel.n.01'),
#  Synset('shih-tzu.n.01'),
#  Synset('pekinese.n.01'),
#  Synset('toy_terrier.n.01'),
#  Synset('japanese_spaniel.n.01'),
#  Synset('maltese_dog.n.01'),
#  Synset('sennenhunde.n.01'),
#  Synset('sled_dog.n.01'),
#  Synset('saint_bernard.n.01'),
#  Synset('police_dog.n.01'),
#  Synset('shepherd_dog.n.01'),
#  Synset('bull_mastiff.n.01'),
#  Synset('seizure-alert_dog.n.01'),
#  Synset('bulldog.n.01'),
#  Synset('watchdog.n.02'),
#  Synset('eskimo_dog.n.01'),
#  Synset('mastiff.n.01'),
#  Synset('guide_dog.n.01'),
#  Synset('boxer.n.04'),
#  Synset('great_dane.n.01'),
#  Synset('hearing_dog.n.01'),
#  Synset('courser.n.03'),
#  Synset('rhodesian_ridgeback.n.01'),
#  Synset('dachshund.n.01'),
#  Synset('hound.n.01'),
#  Synset('sporting_dog.n.01'),
#  Synset('terrier.n.01'),
#  Synset('papillon.n.01'),
#  Synset('english_toy_spaniel.n.01'),
#  Synset('king_charles_spaniel.n.01'),
#  Synset('bernese_mountain_dog.n.01'),
#  Synset('entlebucher.n.01'),
#  Synset('greater_swiss_mountain_dog.n.01'),
#  Synset('appenzeller.n.01'),
#  Synset('malamute.n.01'),
#  Synset('siberian_husky.n.01'),
#  Synset('shetland_sheepdog.n.01'),
#  Synset('border_collie.n.01'),
#  Synset('old_english_sheepdog.n.01'),
#  Synset('belgian_sheepdog.n.01'),
#  Synset('collie.n.01'),
#  Synset('rottweiler.n.01'),
#  Synset('komondor.n.01'),
#  Synset('kelpie.n.02'),
#  Synset('german_shepherd.n.01'),
#  Synset('briard.n.01'),
#  Synset('bouvier_des_flandres.n.01'),
#  Synset('french_bulldog.n.01'),
#  Synset('housedog.n.01'),
#  Synset('kuvasz.n.01'),
#  Synset('pinscher.n.01'),
#  Synset('schipperke.n.01'),
#  Synset('attack_dog.n.01'),
#  Synset('tibetan_mastiff.n.01'),
#  Synset('seeing_eye_dog.n.01'),
#  Synset('sausage_dog.n.01'),
#  Synset('norwegian_elkhound.n.01'),
#  Synset('beagle.n.01'),
#  Synset('ibizan_hound.n.01'),
#  Synset('wolfhound.n.01'),
#  Synset('weimaraner.n.01'),
#  Synset('boarhound.n.01'),
#  Synset('bluetick.n.01'),
#  Synset('coonhound.n.01'),
#  Synset('basset.n.01'),
#  Synset('harrier.n.02'),
#  Synset('afghan_hound.n.01'),
#  Synset('staghound.n.01'),
#  Synset('scottish_deerhound.n.01'),
#  Synset('bloodhound.n.01'),
#  Synset('redbone.n.01'),
#  Synset('foxhound.n.01'),
#  Synset('saluki.n.01'),
#  Synset('greyhound.n.01'),
#  Synset('otterhound.n.01'),
#  Synset('plott_hound.n.01'),
#  Synset('setter.n.02'),
#  Synset('pointer.n.04'),
#  Synset('retriever.n.01'),
#  Synset('water_dog.n.02'),
#  Synset('spaniel.n.01'),
#  Synset('griffon.n.03'),
#  Synset('bird_dog.n.01'),
#  Synset('tibetan_terrier.n.01'),
#  Synset('bullterrier.n.01'),
#  Synset('norwich_terrier.n.01'),
#  Synset('cairn.n.02'),
#  Synset('soft-coated_wheaten_terrier.n.01'),
#  Synset('lhasa.n.02'),
#  Synset('schnauzer.n.01'),
#  Synset('border_terrier.n.01'),
#  Synset('norfolk_terrier.n.01'),
#  Synset('boston_bull.n.01'),
#  Synset('bedlington_terrier.n.01'),
#  Synset('airedale.n.01'),
#  Synset('fox_terrier.n.01'),
#  Synset('rat_terrier.n.01'),
#  Synset('kerry_blue_terrier.n.01'),
#  Synset('scotch_terrier.n.01'),
#  Synset('irish_terrier.n.01'),
#  Synset('silky_terrier.n.01'),
#  Synset('skye_terrier.n.01'),
#  Synset('australian_terrier.n.01'),
#  Synset('yorkshire_terrier.n.01'),
#  Synset('west_highland_white_terrier.n.01'),
#  Synset('wirehair.n.01'),
#  Synset('dandie_dinmont.n.01'),
#  Synset('blenheim_spaniel.n.01'),
#  Synset('groenendael.n.01'),
#  Synset('malinois.n.01'),
#  Synset('miniature_pinscher.n.01'),
#  Synset('affenpinscher.n.01'),
#  Synset('doberman.n.01'),
#  Synset('borzoi.n.01'),
#  Synset('irish_wolfhound.n.01'),
#  Synset('coondog.n.01'),
#  Synset('black-and-tan_coonhound.n.01'),
#  Synset('american_foxhound.n.01'),
#  Synset('english_foxhound.n.01'),
#  Synset('walker_hound.n.01'),
#  Synset('whippet.n.01'),
#  Synset('italian_greyhound.n.01'),
#  Synset('gordon_setter.n.01'),
#  Synset('irish_setter.n.01'),
#  Synset('english_setter.n.01'),
#  Synset('german_short-haired_pointer.n.01'),
#  Synset('vizsla.n.01'),
#  Synset('labrador_retriever.n.01'),
#  Synset('curly-coated_retriever.n.01'),
#  Synset('chesapeake_bay_retriever.n.01'),
#  Synset('flat-coated_retriever.n.01'),
#  Synset('golden_retriever.n.01'),
#  Synset('water_spaniel.n.01'),
#  Synset('cocker_spaniel.n.01'),
#  Synset('clumber.n.01'),
#  Synset('springer_spaniel.n.01'),
#  Synset('sussex_spaniel.n.01'),
#  Synset('brittany_spaniel.n.01'),
#  Synset('field_spaniel.n.01'),
#  Synset('staffordshire_bullterrier.n.01'),
#  Synset('american_staffordshire_terrier.n.01'),
#  Synset('giant_schnauzer.n.01'),
#  Synset('miniature_schnauzer.n.01'),
#  Synset('standard_schnauzer.n.01'),
#  Synset('smooth-haired_fox_terrier.n.01'),
#  Synset('wire-haired_fox_terrier.n.01'),
#  Synset('manchester_terrier.n.01'),
#  Synset('clydesdale_terrier.n.01'),
#  Synset('welsh_terrier.n.01'),
#  Synset('lakeland_terrier.n.01'),
#  Synset('american_water_spaniel.n.01'),
#  Synset('irish_water_spaniel.n.01'),
#  Synset('welsh_springer_spaniel.n.01'),
#  Synset('english_springer.n.01'),
#  Synset('toy_manchester.n.01'),
#  Synset('sealyham_terrier.n.01')]

# %%
list(dog.closure(hyper))
# Out:
# [Synset('domestic_animal.n.01'),
#  Synset('canine.n.02'),
#  Synset('animal.n.01'),
#  Synset('carnivore.n.01'),
#  Synset('organism.n.01'),
#  Synset('placental.n.01'),
#  Synset('living_thing.n.01'),
#  Synset('mammal.n.01'),
#  Synset('whole.n.02'),
#  Synset('vertebrate.n.01'),
#  Synset('object.n.01'),
#  Synset('chordate.n.01'),
#  Synset('physical_entity.n.01'),
#  Synset('entity.n.01')]
